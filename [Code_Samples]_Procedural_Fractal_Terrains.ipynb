# %%
# !pip install noise
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting noise
#   Downloading noise-1.2.2.zip (132 kB)
#      |████████████████████████████████| 132 kB 5.1 MB/s
# Building wheels for collected packages: noise
#   Building wheel for noise (setup.py) ... done
#   Created wheel for noise: filename=noise-1.2.2-cp37-cp37m-linux_x86_64.whl size=64382 sha256=bf34b10e09c5ef9b7bc2370afa71790121fac6b35d8fb1d262c41ad1d98c3d89
#   Stored in directory: /root/.cache/pip/wheels/50/4f/1d/3e94460751c993553ba1a52b8e571ba6510701b4d0a68ffeea
# Successfully built noise
# Installing collected packages: noise
# Successfully installed noise-1.2.2

# %%
import noise
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

# %% [markdown]
# # Perlin noise

# %% [markdown]
# ## 1D

# %%
start, stop, step = 200, 300, 0.1
frequency = 0.05
amplitude = 1

xx = np.arange(start, stop, step)
yy = np.array([noise.pnoise1(frequency*x) for x in xx])  # Perlin noise

plt.figure(figsize=(9,3))
plt.plot(xx, amplitude*yy, color='black')
plt.title(f'Perlin noise (1D) [f={frequency}] [A={amplitude}]')
plt.xlabel('x'), plt.ylabel(f'{amplitude}·perlin({frequency}·x)')
# Out:
# (Text(0.5, 0, 'x'), Text(0, 0.5, '1·perlin(0.05·x)'))

# %% [markdown]
# ### Parameters

# %% [markdown]
# #### Amplitude (A)

# %%
start, stop, step = 200, 300, 0.1
frequency = 0.05
amplitude = 1

xx = np.arange(start, stop, step)
yy = np.array([noise.pnoise1(frequency*x) for x in xx])

plt.figure(figsize=(9,3))
plt.plot(xx, amplitude*yy, color='black')
plt.title(f'Perlin noise (1D) [f={frequency}] [A={amplitude}]')
plt.xlabel('x'), plt.ylabel(f'{amplitude}·perlin({frequency}·x)')
plt.ylim(-10, 10)
# Out:
# (-10.0, 10.0)

# %%
start, stop, step = 200, 300, 0.1
frequency = 0.05
amplitude = 5

xx = np.arange(start, stop, step)
yy = np.array([noise.pnoise1(frequency*x) for x in xx])

plt.figure(figsize=(9,3))
plt.plot(xx, amplitude*yy, color='black')
plt.title(f'Perlin noise (1D) [f={frequency}] [A={amplitude}]')
plt.xlabel('x'), plt.ylabel(f'{amplitude}·perlin({frequency}·x)')
plt.ylim(-10, 10)
# Out:
# (-10.0, 10.0)

# %%
start, stop, step = 200, 300, 0.1
frequency = 0.05
amplitude = 10

xx = np.arange(start, stop, step)
yy = np.array([noise.pnoise1(frequency*x) for x in xx])

plt.figure(figsize=(9,3))
plt.plot(xx, amplitude*yy, color='black')
plt.title(f'Perlin noise (1D) [f={frequency}] [A={amplitude}]')
plt.xlabel('x'), plt.ylabel(f'{amplitude}·perlin({frequency}·x)')
plt.ylim(-10, 10)
# Out:
# (-10.0, 10.0)

# %% [markdown]
# #### Frequency (f)

# %%
start, stop, step = 200, 300, 0.1
frequency = 0.02
amplitude = 1

xx = np.arange(start, stop, step)
yy = np.array([noise.pnoise1(frequency*x) for x in xx])

plt.figure(figsize=(9,3))
plt.plot(xx, amplitude*yy, color='black')
plt.title(f'Perlin noise (1D) [f={frequency}] [A={amplitude}]')
plt.xlabel('x'), plt.ylabel(f'{amplitude}·perlin({frequency}·x)')
# Out:
# (Text(0.5, 0, 'x'), Text(0, 0.5, '1·perlin(0.02·x)'))

# %%
start, stop, step = 200, 300, 0.1
frequency = 0.05
amplitude = 1

xx = np.arange(start, stop, step)
yy = np.array([noise.pnoise1(frequency*x) for x in xx])

plt.figure(figsize=(9,3))
plt.plot(xx, amplitude*yy, color='black')
plt.title(f'Perlin noise (1D) [f={frequency}] [A={amplitude}]')
plt.xlabel('x'), plt.ylabel(f'{amplitude}·perlin({frequency}·x)')
# Out:
# (Text(0.5, 0, 'x'), Text(0, 0.5, '1·perlin(0.05·x)'))

# %%
start, stop, step = 200, 300, 0.1
frequency = 0.1
amplitude = 1

xx = np.arange(start, stop, step)
yy = np.array([noise.pnoise1(frequency*x) for x in xx])

plt.figure(figsize=(9,3))
plt.plot(xx, amplitude*yy, color='black')
plt.title(f'Perlin noise (1D) [f={frequency}] [A={amplitude}]')
plt.xlabel('x'), plt.ylabel(f'{amplitude}·perlin({frequency}·x)')
# Out:
# (Text(0.5, 0, 'x'), Text(0, 0.5, '1·perlin(0.1·x)'))

# %% [markdown]
# ## 2D

# %%
start, stop, step = 200, 300, 0.1
frequency = 0.05
amplitude = 1

xx = np.arange(start, stop, step)
shape = (xx.size, xx.size)

yy = np.zeros(shape)
for i in range(shape[0]):
    for j in range(shape[1]):
        yy[i][j] = noise.pnoise2(frequency*xx[i], frequency*xx[j])

plt.figure(figsize=(8,7))
plt.pcolor(xx, xx, amplitude*yy, cmap='gray', vmin=-amplitude, vmax=+amplitude)
plt.title(f'Perlin noise (2D) [f={frequency}] [A={amplitude}]: {amplitude}·perlin({frequency}·x)')
plt.xlabel('$x_1$'), plt.ylabel('$x_2$')
plt.colorbar()

# %% [markdown]
# ### Parameters

# %% [markdown]
# #### Amplitude (A)

# %%
start, stop, step = 200, 300, 0.1
frequency = 0.05
amplitude = 1

xx = np.arange(start, stop, step)
shape = (xx.size, xx.size)

yy = np.zeros(shape)
for i in range(shape[0]):
    for j in range(shape[1]):
        yy[i][j] = noise.pnoise2(frequency*xx[i], frequency*xx[j])

plt.figure(figsize=(8,7))
plt.pcolor(xx, xx, amplitude*yy, cmap='gray', vmin=-10, vmax=+10)
plt.title(f'Perlin noise (2D) [f={frequency}] [A={amplitude}]: {amplitude}·perlin({frequency}·x)')
plt.xlabel('$x_1$'), plt.ylabel('$x_2$')
plt.colorbar()

# %%
start, stop, step = 200, 300, 0.1
frequency = 0.05
amplitude = 5

xx = np.arange(start, stop, step)
shape = (xx.size, xx.size)

yy = np.zeros(shape)
for i in range(shape[0]):
    for j in range(shape[1]):
        yy[i][j] = noise.pnoise2(frequency*xx[i], frequency*xx[j])

plt.figure(figsize=(8,7))
plt.pcolor(xx, xx, amplitude*yy, cmap='gray', vmin=-10, vmax=+10)
plt.title(f'Perlin noise (2D) [f={frequency}] [A={amplitude}]: {amplitude}·perlin({frequency}·x)')
plt.xlabel('$x_1$'), plt.ylabel('$x_2$')
plt.colorbar()

# %%
start, stop, step = 200, 300, 0.1
frequency = 0.05
amplitude = 10

xx = np.arange(start, stop, step)
shape = (xx.size, xx.size)

yy = np.zeros(shape)
for i in range(shape[0]):
    for j in range(shape[1]):
        yy[i][j] = noise.pnoise2(frequency*xx[i], frequency*xx[j])

plt.figure(figsize=(8,7))
plt.pcolor(xx, xx, amplitude*yy, cmap='gray', vmin=-10, vmax=+10)
plt.title(f'Perlin noise (2D) [f={frequency}] [A={amplitude}]: {amplitude}·perlin({frequency}·x)')
plt.xlabel('$x_1$'), plt.ylabel('$x_2$')
plt.colorbar()

# %% [markdown]
# #### Frequency (f)

# %%
start, stop, step = 200, 300, 0.1
frequency = 0.02
amplitude = 1

xx = np.arange(start, stop, step)
shape = (xx.size, xx.size)

yy = np.zeros(shape)
for i in range(shape[0]):
    for j in range(shape[1]):
        yy[i][j] = noise.pnoise2(frequency*xx[i], frequency*xx[j])

plt.figure(figsize=(8,7))
plt.pcolor(xx, xx, amplitude*yy, cmap='gray', vmin=-amplitude, vmax=+amplitude)
plt.title(f'Perlin noise (2D) [f={frequency}] [A={amplitude}]: {amplitude}·perlin({frequency}·x)')
plt.xlabel('$x_1$'), plt.ylabel('$x_2$')
plt.colorbar()

# %%
start, stop, step = 200, 300, 0.1
frequency = 0.05
amplitude = 1

xx = np.arange(start, stop, step)
shape = (xx.size, xx.size)

yy = np.zeros(shape)
for i in range(shape[0]):
    for j in range(shape[1]):
        yy[i][j] = noise.pnoise2(frequency*xx[i], frequency*xx[j])

plt.figure(figsize=(8,7))
plt.pcolor(xx, xx, amplitude*yy, cmap='gray', vmin=-amplitude, vmax=+amplitude)
plt.title(f'Perlin noise (2D) [f={frequency}] [A={amplitude}]: {amplitude}·perlin({frequency}·x)')
plt.xlabel('$x_1$'), plt.ylabel('$x_2$')
plt.colorbar()

# %%
start, stop, step = 200, 300, 0.1
frequency = 0.1
amplitude = 1

xx = np.arange(start, stop, step)
shape = (xx.size, xx.size)

yy = np.zeros(shape)
for i in range(shape[0]):
    for j in range(shape[1]):
        yy[i][j] = noise.pnoise2(frequency*xx[i], frequency*xx[j])

plt.figure(figsize=(8,7))
plt.pcolor(xx, xx, amplitude*yy, cmap='gray', vmin=-amplitude, vmax=+amplitude)
plt.title(f'Perlin noise (2D) [f={frequency}] [A={amplitude}]: {amplitude}·perlin({frequency}·x)')
plt.xlabel('$x_1$'), plt.ylabel('$x_2$')
plt.colorbar()

# %% [markdown]
# # Fractal Brownian Motion (fBM)

# %% [markdown]
# ## 1D

# %%
start, stop, step = 200, 300, 0.1

# Perlin parameters
frequency = 0.05
amplitude = 1

# fBM parameters
octaves = 4
lacunarity = 2
h = 0.1

xx = np.arange(start, stop, step)
yy = np.zeros(xx.size)
for i, x in enumerate(xx):
  A, f = amplitude, frequency
  for o in range(octaves):
    A *= lacunarity**(-h*o)
    yy[i] += A*noise.pnoise1(f*x)
    f *= lacunarity

plt.figure(figsize=(9,3))
plt.plot(xx, yy, color='black')
plt.title(f'fBM (1D) [f={frequency}] [A={amplitude}] [O={octaves}] [L={lacunarity}] [H={h}]')
plt.xlabel('x'), plt.ylabel('fBM(x)')
# Out:
# (Text(0.5, 0, 'x'), Text(0, 0.5, 'fBM(x)'))

# %% [markdown]
# ### Parameters

# %% [markdown]
# #### Basis function

# %%
start, stop, step = 200, 300, 0.1

# Perlin parameters
frequency = 0.05
amplitude = 1

# fBM parameters
octaves = 4
lacunarity = 2
h = 0.1

xx = np.arange(start, stop, step)
yy = np.zeros(xx.size)
for i, x in enumerate(xx):
  A, f = amplitude, frequency
  for o in range(octaves):
    A *= lacunarity**(-h*o)
    yy[i] += A*noise.pnoise1(f*x)
    f *= lacunarity

plt.figure(figsize=(9,3))
plt.plot(xx, yy, color='black')
plt.title(f'fBM (1D) [f={frequency}] [A={amplitude}] [O={octaves}] [L={lacunarity}] [H={h}]')
plt.xlabel('x'), plt.ylabel('fBM(x)')
# Out:
# (Text(0.5, 0, 'x'), Text(0, 0.5, 'fBM(x)'))

# %%
start, stop, step = 200, 300, 0.1

# Perlin parameters
frequency = 0.05
amplitude = 1

# fBM parameters
octaves = 4
lacunarity = 2
h = 0.1

xx = np.arange(start, stop, step)
yy = np.zeros(xx.size)
for i, x in enumerate(xx):
  A, f = amplitude, frequency
  for o in range(octaves):
    A *= lacunarity**(-h*o)
    yy[i] += A*np.sin(f*x)
    f *= lacunarity

plt.figure(figsize=(9,3))
plt.plot(xx, yy, color='black')
plt.title(f'fBM (1D) [f={frequency}] [A={amplitude}] [O={octaves}] [L={lacunarity}] [H={h}]')
plt.xlabel('x'), plt.ylabel(f'fBM(x)')
# Out:
# (Text(0.5, 0, 'x'), Text(0, 0.5, 'fBM(x)'))

# %% [markdown]
# #### Octaves (O)

# %%
start, stop, step = 200, 300, 0.1

# Perlin parameters
frequency = 0.05
amplitude = 1

# fBM parameters
octaves = 1
lacunarity = 2
h = 0.1

xx = np.arange(start, stop, step)
yy = np.zeros(xx.size)
for i, x in enumerate(xx):
  A, f = amplitude, frequency
  for o in range(octaves):
    A *= lacunarity**(-h*o)
    yy[i] += A*noise.pnoise1(f*x)
    f *= lacunarity

plt.figure(figsize=(9,3))
plt.plot(xx, yy, color='black')
plt.title(f'fBM (1D) [f={frequency}] [A={amplitude}] [O={octaves}] [L={lacunarity}] [H={h}]')
plt.xlabel('x'), plt.ylabel('fBM(x)')
# Out:
# (Text(0.5, 0, 'x'), Text(0, 0.5, 'fBM(x)'))

# %%
start, stop, step = 200, 300, 0.1

# Perlin parameters
frequency = 0.05
amplitude = 1

# fBM parameters
octaves = 4
lacunarity = 2
h = 0.1

xx = np.arange(start, stop, step)
yy = np.zeros(xx.size)
for i, x in enumerate(xx):
  A, f = amplitude, frequency
  for o in range(octaves):
    A *= lacunarity**(-h*o)
    yy[i] += A*noise.pnoise1(f*x)
    f *= lacunarity

plt.figure(figsize=(9,3))
plt.plot(xx, yy, color='black')
plt.title(f'fBM (1D) [f={frequency}] [A={amplitude}] [O={octaves}] [L={lacunarity}] [H={h}]')
plt.xlabel('x'), plt.ylabel('fBM(x)')
# Out:
# (Text(0.5, 0, 'x'), Text(0, 0.5, 'fBM(x)'))

# %%
start, stop, step = 200, 300, 0.1

# Perlin parameters
frequency = 0.05
amplitude = 1

# fBM parameters
octaves = 8
lacunarity = 2
h = 0.1

xx = np.arange(start, stop, step)
yy = np.zeros(xx.size)
for i, x in enumerate(xx):
  A, f = amplitude, frequency
  for o in range(octaves):
    A *= lacunarity**(-h*o)
    yy[i] += A*noise.pnoise1(f*x)
    f *= lacunarity

plt.figure(figsize=(9,3))
plt.plot(xx, yy, color='black')
plt.title(f'fBM (1D) [f={frequency}] [A={amplitude}] [O={octaves}] [L={lacunarity}] [H={h}]')
plt.xlabel('x'), plt.ylabel('fBM(x)')
# Out:
# (Text(0.5, 0, 'x'), Text(0, 0.5, 'fBM(x)'))

# %% [markdown]
# #### Lacunarity (L)

# %%
start, stop, step = 200, 300, 0.1

# Perlin parameters
frequency = 0.05
amplitude = 1

# fBM parameters
octaves = 4
lacunarity = 2
h = 0.1

xx = np.arange(start, stop, step)
yy = np.zeros(xx.size)
for i, x in enumerate(xx):
  A, f = amplitude, frequency
  for o in range(octaves):
    A *= lacunarity**(-h*o)
    yy[i] += A*noise.pnoise1(f*x)
    f *= lacunarity

plt.figure(figsize=(9,3))
plt.plot(xx, yy, color='black')
plt.title(f'fBM (1D) [f={frequency}] [A={amplitude}] [O={octaves}] [L={lacunarity}] [H={h}]')
plt.xlabel('x'), plt.ylabel('fBM(x)')
# Out:
# (Text(0.5, 0, 'x'), Text(0, 0.5, 'fBM(x)'))

# %%
start, stop, step = 200, 300, 0.1

# Perlin parameters
frequency = 0.05
amplitude = 1

# fBM parameters
octaves = 4
lacunarity = 4
h = 0.1

xx = np.arange(start, stop, step)
yy = np.zeros(xx.size)
for i, x in enumerate(xx):
  A, f = amplitude, frequency
  for o in range(octaves):
    A *= lacunarity**(-h*o)
    yy[i] += A*noise.pnoise1(f*x)
    f *= lacunarity

plt.figure(figsize=(9,3))
plt.plot(xx, yy, color='black')
plt.title(f'fBM (1D) [f={frequency}] [A={amplitude}] [O={octaves}] [L={lacunarity}] [H={h}]')
plt.xlabel('x'), plt.ylabel('fBM(x)')
# Out:
# (Text(0.5, 0, 'x'), Text(0, 0.5, 'fBM(x)'))

# %%
start, stop, step = 200, 300, 0.1

# Perlin parameters
frequency = 0.05
amplitude = 1

# fBM parameters
octaves = 4
lacunarity = 8
h = 0.1

xx = np.arange(start, stop, step)
yy = np.zeros(xx.size)
for i, x in enumerate(xx):
  A, f = amplitude, frequency
  for o in range(octaves):
    A *= lacunarity**(-h*o)
    yy[i] += A*noise.pnoise1(f*x)
    f *= lacunarity

plt.figure(figsize=(9,3))
plt.plot(xx, yy, color='black')
plt.title(f'fBM (1D) [f={frequency}] [A={amplitude}] [O={octaves}] [L={lacunarity}] [H={h}]')
plt.xlabel('x'), plt.ylabel('fBM(x)')
# Out:
# (Text(0.5, 0, 'x'), Text(0, 0.5, 'fBM(x)'))

# %% [markdown]
# #### Fractal Increment (1-H)

# %%
start, stop, step = 200, 300, 0.1

# Perlin parameters
frequency = 0.05
amplitude = 1

# fBM parameters
octaves = 4
lacunarity = 2
h = 0.00001

xx = np.arange(start, stop, step)
yy = np.zeros(xx.size)
for i, x in enumerate(xx):
  A, f = amplitude, frequency
  for o in range(octaves):
    A *= lacunarity**(-h*o)
    yy[i] += A*noise.pnoise1(f*x)
    f *= lacunarity

plt.figure(figsize=(9,3))
plt.plot(xx, yy, color='black')
plt.title(f'fBM (1D) [f={frequency}] [A={amplitude}] [O={octaves}] [L={lacunarity}] [H={h}]')
plt.xlabel('x'), plt.ylabel('fBM(x)')
# Out:
# (Text(0.5, 0, 'x'), Text(0, 0.5, 'fBM(x)'))

# %%
start, stop, step = 200, 300, 0.1

# Perlin parameters
frequency = 0.05
amplitude = 1

# fBM parameters
octaves = 4
lacunarity = 2
h = 0.5

xx = np.arange(start, stop, step)
yy = np.zeros(xx.size)
for i, x in enumerate(xx):
  A, f = amplitude, frequency
  for o in range(octaves):
    A *= lacunarity**(-h*o)
    yy[i] += A*noise.pnoise1(f*x)
    f *= lacunarity

plt.figure(figsize=(9,3))
plt.plot(xx, yy, color='black')
plt.title(f'fBM (1D) [f={frequency}] [A={amplitude}] [O={octaves}] [L={lacunarity}] [H={h}]')
plt.xlabel('x'), plt.ylabel('fBM(x)')
# Out:
# (Text(0.5, 0, 'x'), Text(0, 0.5, 'fBM(x)'))

# %%
start, stop, step = 200, 300, 0.1

# Perlin parameters
frequency = 0.05
amplitude = 1

# fBM parameters
octaves = 4
lacunarity = 2
h = 0.99

xx = np.arange(start, stop, step)
yy = np.zeros(xx.size)
for i, x in enumerate(xx):
  A, f = amplitude, frequency
  for o in range(octaves):
    A *= lacunarity**(-h*o)
    yy[i] += A*noise.pnoise1(f*x)
    f *= lacunarity

plt.figure(figsize=(9,3))
plt.plot(xx, yy, color='black')
plt.title(f'fBM (1D) [f={frequency}] [A={amplitude}] [O={octaves}] [L={lacunarity}] [H={h}]')
plt.xlabel('x'), plt.ylabel('fBM(x)')
# Out:
# (Text(0.5, 0, 'x'), Text(0, 0.5, 'fBM(x)'))

# %% [markdown]
# ## 2D

# %%
start, stop, step = 200, 300, 0.1

# Perlin parameters
frequency = 0.05
amplitude = 1

# fBM parameters
octaves = 4
lacunarity = 2
h = 0.1

xx = np.arange(start, stop, step)
shape = (xx.size, xx.size)

yy = np.zeros(shape)
for i in range(shape[0]):
    for j in range(shape[1]):
      A, f = amplitude, frequency
      for o in range(octaves):
        A *= lacunarity**(-h*o)
        yy[i][j] += A * noise.pnoise2(f*xx[i], f*xx[j])
        f *= lacunarity

plt.figure(figsize=(8,7))
plt.pcolor(xx, xx, yy, cmap='gray')
plt.title(f'fBM (2D) [f={frequency}] [A={amplitude}] [O={octaves}] [L={lacunarity}] [H={h}]')
plt.xlabel('$x_1$'), plt.ylabel('$x_2$')
plt.colorbar()

# %% [markdown]
# ### Parameters

# %% [markdown]
# #### Basis function

# %%
start, stop, step = 200, 300, 0.1

# Perlin parameters
frequency = 0.05
amplitude = 1

# fBM parameters
octaves = 4
lacunarity = 2
h = 0.1

xx = np.arange(start, stop, step)
shape = (xx.size, xx.size)

yy = np.zeros(shape)
for i in range(shape[0]):
    for j in range(shape[1]):
      A, f = amplitude, frequency
      for o in range(octaves):
        A *= lacunarity**(-h*o)
        yy[i][j] += A * noise.pnoise2(f*xx[i], f*xx[j])
        f *= lacunarity

plt.figure(figsize=(8,7))
plt.pcolor(xx, xx, yy, cmap='gray')
plt.title(f'fBM (2D) [f={frequency}] [A={amplitude}]  [O={octaves}] [L={lacunarity}] [H={h}]')
plt.xlabel('$x_1$'), plt.ylabel('$x_2$')
plt.colorbar()

# %%
start, stop, step = 200, 300, 0.1

# Perlin parameters
frequency = 0.05
amplitude = 1

# fBM parameters
octaves = 4
lacunarity = 2
h = 0.1

xx = np.arange(start, stop, step)
shape = (xx.size, xx.size)

yy = np.zeros(shape)
for i in range(shape[0]):
    for j in range(shape[1]):
      A, f = amplitude, frequency
      for o in range(octaves):
        A *= lacunarity**(-h*o)
        yy[i][j] += A * np.sin(f*xx[i]) * np.sin(f*xx[j])
        f *= lacunarity

plt.figure(figsize=(8,7))
plt.pcolor(xx, xx, yy, cmap='gray')
plt.title(f'fBM (2D) [f={frequency}] [A={amplitude}] [O={octaves}] [L={lacunarity}] [H={h}]')
plt.xlabel('$x_1$'), plt.ylabel('$x_2$')
plt.colorbar()

# %% [markdown]
# #### Octaves (O)

# %%
start, stop, step = 200, 300, 0.1

# Perlin parameters
frequency = 0.05
amplitude = 1

# fBM parameters
octaves = 1
lacunarity = 2
h = 0.1

xx = np.arange(start, stop, step)
shape = (xx.size, xx.size)

yy = np.zeros(shape)
for i in range(shape[0]):
    for j in range(shape[1]):
      A, f = amplitude, frequency
      for o in range(octaves):
        A *= lacunarity**(-h*o)
        yy[i][j] += A * noise.pnoise2(f*xx[i], f*xx[j])
        f *= lacunarity

plt.figure(figsize=(8,7))
plt.pcolor(xx, xx, yy, cmap='gray')
plt.title(f'fBM (2D) [f={frequency}] [A={amplitude}] [O={octaves}] [L={lacunarity}] [H={h}]')
plt.xlabel('$x_1$'), plt.ylabel('$x_2$')
plt.colorbar()

# %%
start, stop, step = 200, 300, 0.1

# Perlin parameters
frequency = 0.05
amplitude = 4

# fBM parameters
octaves = 4
lacunarity = 2
h = 0.1

xx = np.arange(start, stop, step)
shape = (xx.size, xx.size)

yy = np.zeros(shape)
for i in range(shape[0]):
    for j in range(shape[1]):
      A, f = amplitude, frequency
      for o in range(octaves):
        A *= lacunarity**(-h*o)
        yy[i][j] += A * noise.pnoise2(f*xx[i], f*xx[j])
        f *= lacunarity

plt.figure(figsize=(8,7))
plt.pcolor(xx, xx, yy, cmap='gray')
plt.title(f'fBM (2D) [f={frequency}] [A={amplitude}] [O={octaves}] [L={lacunarity}] [H={h}]')
plt.xlabel('$x_1$'), plt.ylabel('$x_2$')
plt.colorbar()

# %%
start, stop, step = 200, 300, 0.1

# Perlin parameters
frequency = 0.05
amplitude = 1

# fBM parameters
octaves = 8
lacunarity = 2
h = 0.1

xx = np.arange(start, stop, step)
shape = (xx.size, xx.size)

yy = np.zeros(shape)
for i in range(shape[0]):
    for j in range(shape[1]):
      A, f = amplitude, frequency
      for o in range(octaves):
        A *= lacunarity**(-h*o)
        yy[i][j] += A * noise.pnoise2(f*xx[i], f*xx[j])
        f *= lacunarity

plt.figure(figsize=(8,7))
plt.pcolor(xx, xx, yy, cmap='gray')
plt.title(f'fBM (2D) [f={frequency}] [A={amplitude}] [O={octaves}] [L={lacunarity}] [H={h}]')
plt.xlabel('$x_1$'), plt.ylabel('$x_2$')
plt.colorbar()

# %% [markdown]
# #### Lacunarity (L)

# %%
start, stop, step = 200, 300, 0.1

# Perlin parameters
frequency = 0.05
amplitude = 1

# fBM parameters
octaves = 4
lacunarity = 2
h = 0.1

xx = np.arange(start, stop, step)
shape = (xx.size, xx.size)

yy = np.zeros(shape)
for i in range(shape[0]):
    for j in range(shape[1]):
      A, f = amplitude, frequency
      for o in range(octaves):
        A *= lacunarity**(-h*o)
        yy[i][j] += A * noise.pnoise2(f*xx[i], f*xx[j])
        f *= lacunarity

plt.figure(figsize=(8,7))
plt.pcolor(xx, xx, yy, cmap='gray')
plt.title(f'fBM (2D) [f={frequency}] [A={amplitude}]  [O={octaves}] [L={lacunarity}] [H={h}]')
plt.xlabel('$x_1$'), plt.ylabel('$x_2$')
plt.colorbar()

# %%
start, stop, step = 200, 300, 0.1

# Perlin parameters
frequency = 0.05
amplitude = 1

# fBM parameters
octaves = 4
lacunarity = 4
h = 0.1

xx = np.arange(start, stop, step)
shape = (xx.size, xx.size)

yy = np.zeros(shape)
for i in range(shape[0]):
    for j in range(shape[1]):
      A, f = amplitude, frequency
      for o in range(octaves):
        A *= lacunarity**(-h*o)
        yy[i][j] += A * noise.pnoise2(f*xx[i], f*xx[j])
        f *= lacunarity

plt.figure(figsize=(8,7))
plt.pcolor(xx, xx, yy, cmap='gray')
plt.title(f'fBM (2D) [f={frequency}] [A={amplitude}]  [O={octaves}] [L={lacunarity}] [H={h}]')
plt.xlabel('$x_1$'), plt.ylabel('$x_2$')
plt.colorbar()

# %%
start, stop, step = 200, 300, 0.1

# Perlin parameters
frequency = 0.05
amplitude = 1

# fBM parameters
octaves = 4
lacunarity = 8
h = 0.1

xx = np.arange(start, stop, step)
shape = (xx.size, xx.size)

yy = np.zeros(shape)
for i in range(shape[0]):
    for j in range(shape[1]):
      A, f = amplitude, frequency
      for o in range(octaves):
        A *= lacunarity**(-h*o)
        yy[i][j] += A * noise.pnoise2(f*xx[i], f*xx[j])
        f *= lacunarity

plt.figure(figsize=(8,7))
plt.pcolor(xx, xx, yy, cmap='gray')
plt.title(f'fBM (2D) [f={frequency}] [A={amplitude}]  [O={octaves}] [L={lacunarity}] [H={h}]')
plt.xlabel('$x_1$'), plt.ylabel('$x_2$')
plt.colorbar()

# %% [markdown]
# #### Fractal Increment (1-H)

# %%
start, stop, step = 200, 300, 0.1

# Perlin parameters
frequency = 0.05
amplitude = 4

# fBM parameters
octaves = 4
lacunarity = 2
h = 0.00001

xx = np.arange(start, stop, step)
shape = (xx.size, xx.size)

yy = np.zeros(shape)
for i in range(shape[0]):
    for j in range(shape[1]):
      A, f = amplitude, frequency
      for o in range(octaves):
        A *= lacunarity**(-h*o)
        yy[i][j] += A * noise.pnoise2(f*xx[i], f*xx[j])
        f *= lacunarity

plt.figure(figsize=(8,7))
plt.pcolor(xx, xx, yy, cmap='gray')
plt.title(f'fBM (2D) [f={frequency}] [A={amplitude}] [O={octaves}] [L={lacunarity}] [H={h}]')
plt.xlabel('$x_1$'), plt.ylabel('$x_2$')
plt.colorbar()

# %%
start, stop, step = 200, 300, 0.1

# Perlin parameters
frequency = 0.05
amplitude = 4

# fBM parameters
octaves = 4
lacunarity = 2
h = 0.5

xx = np.arange(start, stop, step)
shape = (xx.size, xx.size)

yy = np.zeros(shape)
for i in range(shape[0]):
    for j in range(shape[1]):
      A, f = amplitude, frequency
      for o in range(octaves):
        A *= lacunarity**(-h*o)
        yy[i][j] += A * noise.pnoise2(f*xx[i], f*xx[j])
        f *= lacunarity

plt.figure(figsize=(8,7))
plt.pcolor(xx, xx, yy, cmap='gray')
plt.title(f'fBM (2D) [f={frequency}] [A={amplitude}] [O={octaves}] [L={lacunarity}] [H={h}]')
plt.xlabel('$x_1$'), plt.ylabel('$x_2$')
plt.colorbar()

# %%
start, stop, step = 200, 300, 0.1

# Perlin parameters
frequency = 0.05
amplitude = 4

# fBM parameters
octaves = 4
lacunarity = 2
h = 0.99

xx = np.arange(start, stop, step)
shape = (xx.size, xx.size)

yy = np.zeros(shape)
for i in range(shape[0]):
    for j in range(shape[1]):
      A, f = amplitude, frequency
      for o in range(octaves):
        A *= lacunarity**(-h*o)
        yy[i][j] += A * noise.pnoise2(f*xx[i], f*xx[j])
        f *= lacunarity

plt.figure(figsize=(8,7))
plt.pcolor(xx, xx, yy, cmap='gray')
plt.title(f'fBM (2D) [f={frequency}] [A={amplitude}] [O={octaves}] [L={lacunarity}] [H={h}]')
plt.xlabel('$x_1$'), plt.ylabel('$x_2$')
plt.colorbar()

# %% [markdown]
# ### Sampling at different positions

# %%
start, stop, step = 200, 300, 0.1

# Perlin parameters
frequency = 0.05
amplitude = 1

# fBM parameters
octaves = 8
lacunarity = 2
h = 0.1

xx = np.arange(start, stop, step)
shape = (xx.size, xx.size)

yy = np.zeros(shape)
for i in range(shape[0]):
    for j in range(shape[1]):
      A, f = amplitude, frequency
      for o in range(octaves):
        A *= lacunarity**(-h*o)
        yy[i][j] += A * noise.pnoise2(f*xx[i], f*xx[j])
        f *= lacunarity

plt.figure(figsize=(8,7))
plt.pcolor(xx, xx, yy, cmap='gray')
plt.title(f'fBM (2D) [f={frequency}] [A={amplitude}] [O={octaves}] [L={lacunarity}] [H={h}]')
plt.xlabel('$x_1$'), plt.ylabel('$x_2$')
plt.colorbar()

# %%
start, stop, step = 300, 400, 0.1

# Perlin parameters
frequency = 0.05
amplitude = 1

# fBM parameters
octaves = 8
lacunarity = 2
h = 0.1

xx = np.arange(start, stop, step)
shape = (xx.size, xx.size)

yy = np.zeros(shape)
for i in range(shape[0]):
    for j in range(shape[1]):
      A, f = amplitude, frequency
      for o in range(octaves):
        A *= lacunarity**(-h*o)
        yy[i][j] += A * noise.pnoise2(f*xx[i], f*xx[j])
        f *= lacunarity

plt.figure(figsize=(8,7))
plt.pcolor(xx, xx, yy, cmap='gray')
plt.title(f'fBM (2D) [f={frequency}] [A={amplitude}] [O={octaves}] [L={lacunarity}] [H={h}]')
plt.xlabel('$x_1$'), plt.ylabel('$x_2$')
plt.colorbar()

# %%
start, stop, step = 400, 500, 0.1

# Perlin parameters
frequency = 0.05
amplitude = 1

# fBM parameters
octaves = 8
lacunarity = 2
h = 0.1

xx = np.arange(start, stop, step)
shape = (xx.size, xx.size)

yy = np.zeros(shape)
for i in range(shape[0]):
    for j in range(shape[1]):
      A, f = amplitude, frequency
      for o in range(octaves):
        A *= lacunarity**(-h*o)
        yy[i][j] += A * noise.pnoise2(f*xx[i], f*xx[j])
        f *= lacunarity

plt.figure(figsize=(8,7))
plt.pcolor(xx, xx, yy, cmap='gray')
plt.title(f'fBM (2D) [f={frequency}] [A={amplitude}] [O={octaves}] [L={lacunarity}] [H={h}]')
plt.xlabel('$x_1$'), plt.ylabel('$x_2$')
plt.colorbar()

# %% [markdown]
# ### Generating terrains from fBM

# %%
start, stop, step = 200, 300, 0.1

# Perlin parameters
frequency = 0.05
amplitude = 1

# fBM parameters
octaves = 8
lacunarity = 2
h = 0.99

xx = np.arange(start, stop, step)
shape = (xx.size, xx.size)

yy = np.zeros(shape)
for i in range(shape[0]):
    for j in range(shape[1]):
      A, f = amplitude, frequency
      for o in range(octaves):
        A *= lacunarity**(-h*o)
        yy[i][j] += A * noise.pnoise2(f*xx[i], f*xx[j])
        f *= lacunarity

fig, ax = plt.subplots(subplot_kw={"projection": "3d"}, figsize=(8,7))
xx1, xx2 = np.meshgrid(xx, xx)
surf = ax.plot_surface(xx1, xx2, yy, linewidth=0.1)
fig.colorbar(surf, shrink=0.5, aspect=5)
plt.title(f'fBM (2D) [f={frequency}] [A={amplitude}] [O={octaves}] [L={lacunarity}] [H={h}]')
plt.xlabel('$x_1$'), plt.ylabel('$x_2$')
plt.show()

# %%
start, stop, step = 200, 300, 0.1

# Perlin parameters
frequency = 0.05
amplitude = 4

# fBM parameters
octaves = 4
lacunarity = 2
h = 0.99

# terrain
deep_sea = 32*2
medium_sea = 32*4
coast = 32*5
pastures = int(32*5.5)
mountains = 32*6
snow = 32*7

xx = np.arange(start, stop, step)
shape = (xx.size, xx.size)

yy = np.zeros(shape)
for i in range(shape[0]):
    for j in range(shape[1]):
      A, f = amplitude, frequency
      for o in range(octaves):
        A *= lacunarity**(-h*o)
        yy[i][j] += A * noise.pnoise2(f*xx[i], f*xx[j])
        f *= lacunarity
yy += -1 * yy.min()
yy /= yy.max()

original = cm.get_cmap('gray', 256)
newcolors = original(np.linspace(-1, 1, 256))

newcolors[:deep_sea, :] = np.array([21/256, 38/256, 54/256, 1])
newcolors[deep_sea:medium_sea, :] = np.array([37/256, 159/256, 175/256, 1])
newcolors[medium_sea:coast, :] = np.array([180/256, 210/256, 211/256, 1])
newcolors[coast:pastures, :] = np.array([246/256, 215/256, 176/256, 1])
newcolors[pastures:mountains, :] = np.array([50/256, 210/256, 50/256, 1])
newcolors[mountains:snow, :] = np.array([80/256, 80/256, 80/256, 1])
newcolors[snow:, :] = np.array([230/256, 230/256, 230/256, 1])

terrain_cm = ListedColormap(newcolors)

plt.figure(figsize=(8,7))
plt.pcolor(xx, xx, yy, cmap=terrain_cm)
plt.title(f'fBM (2D) [f={frequency}] [A={amplitude}] [O={octaves}] [L={lacunarity}] [H={h}]')
plt.xlabel('$x_1$'), plt.ylabel('$x_2$')
plt.colorbar()

# %%
start, stop, step = 200, 300, 0.1

# Perlin parameters
frequency = 0.05
amplitude = 4

# fBM parameters
octaves = 4
lacunarity = 2
h = 0.99

# terrain
deep_sea = 32*2
medium_sea = 32*4
coast = 32*5
pastures = int(32*5.5)
mountains = 32*6
snow = 32*7

xx = np.arange(start, stop, step)
shape = (xx.size, xx.size)

yy = np.zeros(shape)
for i in range(shape[0]):
    for j in range(shape[1]):
      A, f = amplitude, frequency
      for o in range(octaves):
        A *= lacunarity**(-h*o)
        yy[i][j] += A * noise.pnoise2(f*xx[i], f*xx[j])
        f *= lacunarity
yy += -1 * yy.min()
yy /= yy.max()

original = cm.get_cmap('gray', 256)
newcolors = original(np.linspace(-1, 1, 256))

newcolors[:coast, :] = np.array([37/256, 159/256, 175/256, 1])
newcolors[coast:pastures, :] = np.array([246/256, 215/256, 176/256, 1])
newcolors[pastures:mountains, :] = np.array([50/256, 210/256, 50/256, 1])
newcolors[mountains:snow, :] = np.array([80/256, 80/256, 80/256, 1])
newcolors[snow:, :] = np.array([230/256, 230/256, 230/256, 1])

terrain_cm = ListedColormap(newcolors)

plt.figure(figsize=(8,7))
plt.pcolor(xx, xx, yy, cmap=terrain_cm)
plt.title(f'fBM (2D) [f={frequency}] [A={amplitude}] [O={octaves}] [L={lacunarity}] [H={h}]')
plt.xlabel('$x_1$'), plt.ylabel('$x_2$')
plt.colorbar()

# %% [markdown]
# # Multifractals (multi-fBM) model: Statistics by altitude

# %% [markdown]
# ## 1D

# %%
start, stop, step = 200, 300, 0.1

# Perlin parameters
frequency = 0.05
amplitude = 1

# fBM parameters
octaves = 4
lacunarity = 2
h = 0.1

# multi-fBM (Statistics By Altitude) parameters
offset = 0.1

xx = np.arange(start, stop, step)
yy = np.zeros(xx.size)
for i, x in enumerate(xx):
  f = frequency
  for o in range(octaves):
    if o == 0:
      gain = 1
    else:
      gain = f**(-h*o)
      gain *= yy[i]
    yy[i] += gain * (noise.pnoise1(f*x) + offset)
    f *= lacunarity

plt.figure(figsize=(9,3))
plt.plot(xx, yy, color='black')
plt.title(f'multi-fBM (1D) [f={frequency}] [A={amplitude}] [O={octaves}] [L={lacunarity}] [H={h}] [P={offset}]')
plt.xlabel('x'), plt.ylabel('fBM(x)')
# Out:
# (Text(0.5, 0, 'x'), Text(0, 0.5, 'fBM(x)'))

# %% [markdown]
# ### Parameters

# %% [markdown]
# #### Offset (P)

# %%
start, stop, step = 200, 300, 0.1

# Perlin parameters
frequency = 0.05
amplitude = 1

# fBM parameters
octaves = 4
lacunarity = 2
h = 0.1

# multi-fBM (Statistics By Altitude) parameters
offset = 0

xx = np.arange(start, stop, step)
yy = np.zeros(xx.size)
for i, x in enumerate(xx):
  f = frequency
  for o in range(octaves):
    if o == 0:
      gain = 1
    else:
      gain = f**(-h*o)
      gain *= yy[i]
    yy[i] += gain * (noise.pnoise1(f*x) + offset)
    f *= lacunarity

plt.figure(figsize=(9,3))
plt.plot(xx, yy, color='black')
plt.title(f'multi-fBM (1D) [f={frequency}] [A={amplitude}] [O={octaves}] [L={lacunarity}] [H={h}] [P={offset}]')
plt.xlabel('x'), plt.ylabel('fBM(x)')
# Out:
# (Text(0.5, 0, 'x'), Text(0, 0.5, 'fBM(x)'))

# %%
start, stop, step = 200, 300, 0.1

# Perlin parameters
frequency = 0.05
amplitude = 1

# fBM parameters
octaves = 4
lacunarity = 2
h = 0.1

# multi-fBM (Statistics By Altitude) parameters
offset = 0.8

xx = np.arange(start, stop, step)
yy = np.zeros(xx.size)
for i, x in enumerate(xx):
  f = frequency
  for o in range(octaves):
    if o == 0:
      gain = 1
    else:
      gain = f**(-h*o)
      gain *= yy[i]
    yy[i] += gain * (noise.pnoise1(f*x) + offset)
    f *= lacunarity

plt.figure(figsize=(9,3))
plt.plot(xx, yy, color='black')
plt.title(f'multi-fBM (1D) [f={frequency}] [A={amplitude}] [O={octaves}] [L={lacunarity}] [H={h}] [P={offset}]')
plt.xlabel('x'), plt.ylabel('fBM(x)')
# Out:
# (Text(0.5, 0, 'x'), Text(0, 0.5, 'fBM(x)'))

# %%
start, stop, step = 200, 300, 0.1

# Perlin parameters
frequency = 0.05
amplitude = 1

# fBM parameters
octaves = 4
lacunarity = 2
h = 0.1

# multi-fBM (Statistics By Altitude) parameters
offset = 10

xx = np.arange(start, stop, step)
yy = np.zeros(xx.size)
for i, x in enumerate(xx):
  f = frequency
  for o in range(octaves):
    if o == 0:
      gain = 1
    else:
      gain = f**(-h*o)
      gain *= yy[i]
    yy[i] += gain * (noise.pnoise1(f*x) + offset)
    f *= lacunarity

plt.figure(figsize=(9,3))
plt.plot(xx, yy, color='black')
plt.title(f'multi-fBM (1D) [f={frequency}] [A={amplitude}] [O={octaves}] [L={lacunarity}] [H={h}] [P={offset}]')
plt.xlabel('x'), plt.ylabel('fBM(x)')
# Out:
# (Text(0.5, 0, 'x'), Text(0, 0.5, 'fBM(x)'))

# %% [markdown]
# ## 2D

# %%
start, stop, step = 200, 300, 0.1

# Perlin parameters
frequency = 0.05
amplitude = 1

# fBM parameters
octaves = 4
lacunarity = 2
h = 0.1

# multi-fBM (Statistics By Altitude) parameters
offset = 0.1

xx = np.arange(start, stop, step)
shape = (xx.size, xx.size)

yy = np.zeros(shape)
for i in range(shape[0]):
    for j in range(shape[1]):
      f = frequency
      for o in range(octaves):
        if o == 0:
          gain = 1
        else:
          gain = f**(-h*o)
          gain *= yy[i][j]
        yy[i][j] += gain * (noise.pnoise2(f*xx[i], f*xx[j]) + offset)
        f *= lacunarity

plt.figure(figsize=(8,7))
plt.pcolor(xx, xx, yy, cmap='gray')
plt.title(f'multi-fBM (2D) [f={frequency}] [A={amplitude}] [O={octaves}] [L={lacunarity}] [H={h}] [P={offset}]')
plt.xlabel('$x_1$'), plt.ylabel('$x_2$')
plt.colorbar()

# %% [markdown]
# #### Parameters

# %% [markdown]
# ##### Offset (P)

# %%
start, stop, step = 200, 300, 0.1

# Perlin parameters
frequency = 0.05
amplitude = 1

# fBM parameters
octaves = 4
lacunarity = 2
h = 0.1

# multi-fBM (Statistics By Altitude) parameters
offset = 0

xx = np.arange(start, stop, step)
shape = (xx.size, xx.size)

yy = np.zeros(shape)
for i in range(shape[0]):
    for j in range(shape[1]):
      f = frequency
      for o in range(octaves):
        if o == 0:
          gain = 1
        else:
          gain = f**(-h*o)
          gain *= yy[i][j]
        yy[i][j] += gain * (noise.pnoise2(f*xx[i], f*xx[j]) + offset)
        f *= lacunarity

plt.figure(figsize=(8,7))
plt.pcolor(xx, xx, yy, cmap='gray')
plt.title(f'multi-fBM (2D) [f={frequency}] [A={amplitude}] [O={octaves}] [L={lacunarity}] [H={h}] [P={offset}]')
plt.xlabel('$x_1$'), plt.ylabel('$x_2$')
plt.colorbar()

# %%
start, stop, step = 200, 300, 0.1

# Perlin parameters
frequency = 0.05
amplitude = 1

# fBM parameters
octaves = 4
lacunarity = 2
h = 0.1

# multi-fBM (Statistics By Altitude) parameters
offset = 0.8

xx = np.arange(start, stop, step)
shape = (xx.size, xx.size)

yy = np.zeros(shape)
for i in range(shape[0]):
    for j in range(shape[1]):
      f = frequency
      for o in range(octaves):
        if o == 0:
          gain = 1
        else:
          gain = f**(-h*o)
          gain *= yy[i][j]
        yy[i][j] += gain * (noise.pnoise2(f*xx[i], f*xx[j]) + offset)
        f *= lacunarity

plt.figure(figsize=(8,7))
plt.pcolor(xx, xx, yy, cmap='gray')
plt.title(f'multi-fBM (2D) [f={frequency}] [A={amplitude}] [O={octaves}] [L={lacunarity}] [H={h}] [P={offset}]')
plt.xlabel('$x_1$'), plt.ylabel('$x_2$')
plt.colorbar()

# %%
start, stop, step = 200, 300, 0.1

# Perlin parameters
frequency = 0.05
amplitude = 1

# fBM parameters
octaves = 4
lacunarity = 2
h = 0.1

# multi-fBM (Statistics By Altitude) parameters
offset = 10

xx = np.arange(start, stop, step)
shape = (xx.size, xx.size)

yy = np.zeros(shape)
for i in range(shape[0]):
    for j in range(shape[1]):
      f = frequency
      for o in range(octaves):
        if o == 0:
          gain = 1
        else:
          gain = f**(-h*o)
          gain *= yy[i][j]
        yy[i][j] += gain * (noise.pnoise2(f*xx[i], f*xx[j]) + offset)
        f *= lacunarity

plt.figure(figsize=(8,7))
plt.pcolor(xx, xx, yy, cmap='gray')
plt.title(f'multi-fBM (2D) [f={frequency}] [A={amplitude}] [O={octaves}] [L={lacunarity}] [H={h}] [P={offset}]')
plt.xlabel('$x_1$'), plt.ylabel('$x_2$')
plt.colorbar()

# %% [markdown]
# #### Generating terrains from Statistics By Altitude

# %%
start, stop, step = 200, 300, 0.1

# Perlin parameters
frequency = 0.05
amplitude = 1

# fBM parameters
octaves = 4
lacunarity = 2
h = 0.1

# multi-fBM (Statistics By Altitude) parameters
offset = 0.8

# terrain
deep_sea = 32
medium_sea = 32*2
coast = 32*4
pastures = int(32*2)
mountains = 32*6
snow = 32*8

xx = np.arange(start, stop, step)
shape = (xx.size, xx.size)

yy = np.zeros(shape)
for i in range(shape[0]):
    for j in range(shape[1]):
      f = frequency
      for o in range(octaves):
        if o == 0:
          gain = 1
        else:
          gain = f**(-h*o)
          gain *= yy[i][j]
        yy[i][j] += gain * (noise.pnoise2(f*xx[i], f*xx[j]) + offset)
        f *= lacunarity

yy += -1 * yy.min()
yy /= yy.max()

original = cm.get_cmap('gray', 256)
newcolors = original(np.linspace(-1, 1, 256))

#newcolors[:deep_sea, :] = np.array([21/256, 38/256, 54/256, 1])
#newcolors[deep_sea:medium_sea, :] = np.array([37/256, 159/256, 175/256, 1])
#newcolors[medium_sea:coast, :] = np.array([180/256, 210/256, 211/256, 1])
newcolors[:pastures, :] = np.array([246/256, 215/256, 176/256, 1])
newcolors[pastures:mountains, :] = np.array([50/256, 210/256, 50/256, 1])
newcolors[mountains:snow, :] = np.array([80/256, 80/256, 80/256, 1])
newcolors[snow:, :] = np.array([230/256, 230/256, 230/256, 1])

terrain_cm = ListedColormap(newcolors)

plt.figure(figsize=(8,7))
plt.pcolor(xx, xx, yy, cmap=terrain_cm)
plt.title(f'fBM (2D) [f={frequency}] [A={amplitude}] [O={octaves}] [L={lacunarity}] [H={h}]')
plt.xlabel('$x_1$'), plt.ylabel('$x_2$')
plt.colorbar()

# %% [markdown]
# # Color texture pipeline

# %%
def fbm(start, stop, step,  # general params
        frequency, amplitude,  # perlin params
        octaves, lacunarity, h):  # fBM params
  xx = np.arange(start, stop, step)
  shape = (xx.size, xx.size)

  yy = np.zeros(shape)
  for i in range(shape[0]):
      for j in range(shape[1]):
        A, f = amplitude, frequency
        for o in range(octaves):
          A *= lacunarity**(-h*o)
          yy[i][j] += A * noise.pnoise2(f*xx[i], f*xx[j])
          f *= lacunarity

  return yy


def normalize(x):
  x += -1 * x.min()
  x /= x.max()
  return x


def fbm_altitude(start, stop, step,  # general params
                 frequency, amplitude,  # perlin params
                 octaves, lacunarity, h,  # fBM params
                 offset):  # statistics by altitutde params
  xx = np.arange(start, stop, step)
  shape = (xx.size, xx.size)

  yy = np.zeros(shape)
  for i in range(shape[0]):
      for j in range(shape[1]):
        f = frequency
        for o in range(octaves):
          if o == 0:
            gain = 1
          else:
            gain = f**(-h*o)
            gain *= yy[i][j]
          yy[i][j] += gain * (noise.pnoise2(f*xx[i], f*xx[j]) + offset)
          f *= lacunarity
  return yy

# %%
############## generate heightmap ##############

start=1200
stop=1300
step=0.1
frequency=0.05
amplitude=1
octaves=4
lacunarity=2
h=0.99

heightmap = normalize(fbm(
    start=start,
    stop=stop,
    step=step,
    frequency=frequency,
    amplitude=amplitude,
    octaves=octaves,
    lacunarity=lacunarity,
    h=h))

plt.figure()
plt.imshow(heightmap, cmap='gray')
plt.axis('off')
plt.savefig(f'heighMap_fBM_f{frequency}_A{amplitude}_O{octaves}_L{lacunarity}_H{h}.png',bbox_inches='tight', pad_inches=0)

########### generate colormap noise #############
# a perfect correspondence between heights
# and colors (snow, rock, ...) is not realistic
# we generate some noise to add a bit of spice and variation

cmap_noise = normalize(fbm(
    start=200,
    stop=300,
    step=0.1,
    frequency=0.02,
    amplitude=1,
    octaves=8,
    lacunarity=2,
    h=0.99))

plt.figure()
plt.imshow(cmap_noise, cmap='gray')
plt.axis('off')

############### generate colormap ###############
coast = 50
pastures = 70
mountains = 120
top_mountains = 150
snow = 200

original = cm.get_cmap('gray', 256)
cmap = original(np.linspace(-1, 1, 256))
cmap[:coast, :] = np.array([37/256, 159/256, 175/256, 1])
cmap[coast:pastures, :] = np.array([246/256, 215/256, 176/256, 1])
cmap[pastures:mountains, :] = np.array([110/256, 204/256, 126/256, 1])
cmap[mountains:top_mountains, :] = np.array([74/256, 71/256, 63/256, 1])
cmap[top_mountains:snow, :] = np.array([79/256, 78/256, 77/256, 1])
cmap[snow:, :] = np.array([235/256, 231/256, 218/256, 1])

plt.figure()
plt.imshow(normalize(heightmap + cmap_noise / 5), cmap=ListedColormap(cmap))
plt.axis('off')
plt.savefig(f'colorMap_fBM_f{frequency}_A{amplitude}_O{octaves}_L{lacunarity}_H{h}.png',bbox_inches='tight', pad_inches=0)

# %%
############## generate heightmap ##############
start=200
stop=400
step=0.1
frequency=0.005
amplitude=1
octaves=4
lacunarity=2
h=0.99
offset=0.3

heightmap = normalize(fbm_altitude(
    start=start,
    stop=stop,
    step=step,
    frequency=frequency,
    amplitude=amplitude,
    octaves=octaves,
    lacunarity=lacunarity,
    h=h,
    offset=offset))

plt.figure()
plt.imshow(heightmap, cmap='gray')
plt.axis('off')
plt.savefig(f'heighMap_multi-fBM_f{frequency}_A{amplitude}_O{octaves}_L{lacunarity}_H{h}_offset{offset}.png',bbox_inches='tight', pad_inches=0)

########### generate colormap noise #############
# a perfect correspondence between heights
# and colors (snow, rock, ...) is not realistic
# we generate some noise to add a bit of spice and variation

cmap_noise = normalize(fbm(
    start=200,
    stop=400,
    step=0.1,
    frequency=0.02,
    amplitude=1,
    octaves=8,
    lacunarity=2,
    h=0.99))

plt.figure()
plt.imshow(cmap_noise, cmap='gray')
plt.axis('off')

############### generate colormap ###############
coast = 50
pastures = 80
mountains = 120
top_mountains = 150
snow = 200

original = cm.get_cmap('gray', 256)
cmap = original(np.linspace(-1, 1, 256))
cmap[:coast, :] = np.array([37/256, 159/256, 175/256, 1])
cmap[coast:pastures, :] = np.array([246/256, 215/256, 176/256, 1])
cmap[pastures:mountains, :] = np.array([110/256, 204/256, 126/256, 1])
cmap[mountains:top_mountains, :] = np.array([74/256, 71/256, 63/256, 1])
cmap[top_mountains:snow, :] = np.array([79/256, 78/256, 77/256, 1])
cmap[snow:, :] = np.array([235/256, 231/256, 218/256, 1])

plt.figure()
plt.imshow(normalize(heightmap + cmap_noise / 5), cmap=ListedColormap(cmap))
plt.axis('off')
plt.savefig(f'colorMap_multi-fBM_f{frequency}_A{amplitude}_O{octaves}_L{lacunarity}_H{h}_offset{offset}.png',bbox_inches='tight', pad_inches=0)
